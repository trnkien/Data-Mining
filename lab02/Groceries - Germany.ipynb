# %%
pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in /Users/trkien/opt/anaconda3/lib/python3.9/site-packages (0.21.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in /Users/trkien/opt/anaconda3/lib/python3.9/site-packages (from mlxtend) (1.0.2)
# Requirement already satisfied: setuptools in /Users/trkien/opt/anaconda3/lib/python3.9/site-packages (from mlxtend) (61.2.0)
# Requirement already satisfied: pandas>=0.24.2 in /Users/trkien/opt/anaconda3/lib/python3.9/site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /Users/trkien/opt/anaconda3/lib/python3.9/site-packages (from mlxtend) (3.5.1)
# Requirement already satisfied: joblib>=0.13.2 in /Users/trkien/opt/anaconda3/lib/python3.9/site-packages (from mlxtend) (1.1.0)
# Requirement already satisfied: numpy>=1.16.2 in /Users/trkien/opt/anaconda3/lib/python3.9/site-packages (from mlxtend) (1.21.5)
# Requirement already satisfied: scipy>=1.2.1 in /Users/trkien/opt/anaconda3/lib/python3.9/site-packages (from mlxtend) (1.7.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/trkien/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/trkien/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/trkien/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/trkien/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (9.0.1)
# Requirement already satisfied: packaging>=20.0 in /Users/trkien/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/trkien/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /Users/trkien/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/trkien/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.24.2->mlxtend) (2021.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/trkien/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in /Users/trkien/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
# 1. ĐỌC DỮ LIỆU VÀO CHƯƠNG TRÌNH

# %%
# Đọc tập tin dữ liệu với định dạng "xlsx"
df = pd.read_excel('Online Retail.xlsx')

# %%
# Hiển thị thông tin
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
# 2. TIỀN XỬ LÝ DỮ LIỆU

# %%
# Thao tác làm sạch dữ liệu 
df['Description'] = df['Description'].str.strip()
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
df['InvoiceNo'] = df['InvoiceNo'].astype('str')

# %%
# Xem thử 10 dòng đầu
df.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 5 2010-12-01 08:26:00       7.65     17850.0  United Kingdom
# 6 2010-12-01 08:26:00       4.25     17850.0  United Kingdom
# 7 2010-12-01 08:28:00       1.85     17850.0  United Kingdom
# 8 2010-12-01 08:28:00       1.85     17850.0  United Kingdom
# 9 2010-12-01 08:34:00       1.69     13047.0  United Kingdom

# %%
# 3. XOÁ HOÁ ĐƠN GHI NỢ
df[df.InvoiceNo.str.contains('C', na=False)].head()
# Out:
#     InvoiceNo StockCode                      Description  Quantity  \
# 141   C536379         D                         Discount        -1
# 154   C536383    35004C  SET OF 3 COLOURED  FLYING DUCKS        -1
# 235   C536391     22556    PLASTERS IN TIN CIRCUS PARADE       -12
# 236   C536391     21984  PACK OF 12 PINK PAISLEY TISSUES       -24
# 237   C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES       -24
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 141 2010-12-01 09:41:00      27.50     14527.0  United Kingdom
# 154 2010-12-01 09:49:00       4.65     15311.0  United Kingdom
# 235 2010-12-01 10:24:00       1.65     17548.0  United Kingdom
# 236 2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# 237 2010-12-01 10:24:00       0.29     17548.0  United Kingdom

# %%
# Xoá những hoá đơn tín dụng
df = df[~df['InvoiceNo'].str.contains('C')]

# %%
# 4. THỐNG KÊ SỐ DÒNG DỮ LIỆU THEO TỪNG QUỐC GIA
df['Country'].value_counts().plot(kind='barh', figsize=(15,10))
# Out:
# <AxesSubplot:>

# %%
# 5. LẤY DỮ LIỆU HOÁ ĐƠN TỪ NƯỚC ANH 'UNITED KINGDOM'VÀ GOM NHÓM

# %%
# Chỉ xét các hoá đơn từ nước Anh và nhóm dữ liệu theo Số hoá đơn và Tên mặt hàng
basket = df[df['Country'] == "Germany"].groupby(['InvoiceNo', 'Description'])['Quantity']

# %%
basket = basket.sum().unstack().reset_index().fillna(0).set_index('InvoiceNo')

# %%
# Xem dữ liệu sau khi chuyển về dạng hot encoding
basket.head(10)
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 
ZINC METAL HEART DECORATION  \
# InvoiceNo
# 536527                                     0.0                          0.0
# 536840                                     0.0                          0.0
# 536861                                     0.0                          0.0
# 536967                                     0.0                          0.0
# 536983                                     0.0                          0.0
# 537197                                     0.0                          0.0
# 537198                                     0.0                          0.0
# 537201                                     0.0                          0.0
# 537212                                     0.0                          0.0
# 537250                                     0.0                          0.0
#
# Description  ZINC T-LIGHT HOLDER STAR LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# InvoiceNo
# 536527                                  0.0                              0.0
# 536840                                  0.0                              0.0
# 536861                                  0.0                              0.0
# 536967                                  0.0                              0.0
# 536983                                  0.0                              0.0
# 537197                                  0.0                              0.0
# 537198                                  0.0                              0.0
# 537201                                  0.0                              0.0
# 537212                                  0.0                              0.0
# 537250                                  0.0                              0.0
#
# Description  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo
# 536527                                    0.0
# 536840                                    0.0
# 536861                                    0.0
# 536967                                    0.0
# 536983                                    0.0
# 537197                                    0.0
# 537198                                    0.0
# 537201                                    0.0
# 537212                                    0.0
# 537250                                    0.0
#
# [10 rows x 1695 columns]

# %%
#7. CHUYỂN ĐỔI DỮ LIỆU TỪ DẠNG HOT ENCODING THÀNH ONE-HOT ENCODING

# %%
# Tạo hàm biến đổi mỗi điểm dữ liệu có số lượng (Quantity) > 0 thành 1
def encode_data(datapoint):
    if datapoint <= 0:
        return 0
    if datapoint >= 1:
        return 1

# %%
# Chuyển đổi dữ liệu từ dạng hot encoding thành one-hot encoding
basket = basket.applymap(encode_data)

# %%
# 8. XOÁ CỘT 'POSTAGE'
basket.drop('POSTAGE', inplace=True, axis=1)

# %%
# 9. TÌM TẬP PHỔ BIẾN BẰNG THUẬT TOÁN APRIORI, min_sup=3%
itemsets = apriori(basket, min_support=0.05, use_colnames=True)
# Out:
# /Users/trkien/opt/anaconda3/lib/python3.9/site-packages/mlxtend/frequent_patterns/fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
itemsets.head(10)
# Out:
#     support                        itemsets
# 0  0.102845        (6 RIBBONS RUSTIC CHARM)
# 1  0.070022     (ALARM CLOCK BAKELIKE PINK)
# 2  0.065646   (CHARLOTTE BAG APPLES DESIGN)
# 3  0.050328  (CHILDRENS CUTLERY DOLLY GIRL)
# 4  0.061269      (COFFEE MUG APPLES DESIGN)
# 5  0.063457    (FAWN BLUE HOT WATER BOTTLE)
# 6  0.072210             (GUMBALL COAT RACK)
# 7  0.056893          (IVORY KITCHEN SCALES)
# 8  0.063457         (JAM JAR WITH PINK LID)
# 9  0.091904        (JAM MAKING SET PRINTED)

# %%
# 10. TẠO LUẬT KẾT HỢP VỚI min_conf=50%

# %%
# Tạo luật kết hợp
rules = association_rules(itemsets, metric="confidence", min_threshold=0.5)

# %%
# Xem thông tin về tập luật
rules.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   antecedents         8 non-null      object
#  1   consequents         8 non-null      object
#  2   antecedent support  8 non-null      float64
#  3   consequent support  8 non-null      float64
#  4   support             8 non-null      float64
#  5   confidence          8 non-null      float64
#  6   lift                8 non-null      float64
#  7   leverage            8 non-null      float64
#  8   conviction          8 non-null      float64
# dtypes: float64(7), object(2)
# memory usage: 704.0+ bytes

# %%
# Chuyển đổi vế trái và vế phải từ kiểu object (fronzenset) về kiểu chuỗi (unicode)
rules["antecedents"] = rules["antecedents"].apply(lambda x: list(x)[0]).astype("unicode")
rules["consequents"] = rules["consequents"].apply(lambda x: list(x)[0]).astype("unicode")

# %%
# Viết lệnh in ra các luật đã tìm được
for i in range(len(rules)):
    print(rules.loc[i, 'antecedents'], ' ==>', rules.loc[i, 'consequents'],
          ' [', rules.loc[i, 'support'], ', ', rules.loc[i, 'confidence'], ']')
# Out:
# PLASTERS IN TIN CIRCUS PARADE  ==> PLASTERS IN TIN WOODLAND ANIMALS  [ 0.06783369803063458 ,  0.5849056603773585 ]
# PLASTERS IN TIN SPACEBOY  ==> PLASTERS IN TIN WOODLAND ANIMALS  [ 0.061269146608315096 ,  0.5714285714285714 ]
# PLASTERS IN TIN WOODLAND ANIMALS  ==> ROUND SNACK BOXES SET OF4 WOODLAND  [ 0.07439824945295405 ,  0.5396825396825397 ]
# RED RETROSPOT CHARLOTTE BAG  ==> WOODLAND CHARLOTTE BAG  [ 0.05908096280087528 ,  0.8437500000000001 ]
# ROUND SNACK BOXES SET OF 4 FRUITS  ==> ROUND SNACK BOXES SET OF4 WOODLAND  [ 0.13129102844638948 ,  0.8333333333333333 ]
# ROUND SNACK BOXES SET OF4 WOODLAND  ==> ROUND SNACK BOXES SET OF 4 FRUITS  [ 0.13129102844638948 ,  0.5357142857142857 ]
# SPACEBOY LUNCH BOX  ==> ROUND SNACK BOXES SET OF4 WOODLAND  [ 0.0700218818380744 ,  0.6808510638297872 ]
# WOODLAND CHARLOTTE BAG  ==> ROUND SNACK BOXES SET OF4 WOODLAND  [ 0.06345733041575492 ,  0.5 ]

# %%
 # 11. BIỂU DIỄN ĐỘ TIN CẬY, ĐỘ HỖ TRỢ CỦA TẬP LUẬT LÊN ĐỒ THỊ PHÂN TÁN

# %%
# Lấy giá trị độ hỗ trợ và độ tin cậy của tập luật
support=rules['support'].values
confidence=rules['confidence'].values

# %%
# Biểu diễn các thông tin này lên biểu đồ
plt.figure(figsize=(6,5))
plt.title('Association Rules')
plt.xlabel('support')
plt.ylabel('confidence')
sns.regplot(x=support, y=confidence, fit_reg=False)
# Out:
# <AxesSubplot:title={'center':'Association Rules'}, xlabel='support', ylabel='confidence'>
